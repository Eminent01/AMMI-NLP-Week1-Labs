# %% [markdown]
# <h1 style="font-family:verdana;font-size:300%;text-align:center;background-color:#f2f2f2;color:#0d0d0d">AMMI NLP - Review sessions</h1>
#
# <h1 style="font-family:verdana;font-size:180%;text-align:Center;color:#993333"> Lab 3: n-gram models </h1>

# %% [markdown]
# **Big thanks to Amr Khalifa who improved this lab and made it to a Jupyter Notebook!**

# %%
import io, sys, math, re
from collections import defaultdict
import numpy as np

# %%
# data_loader
def load_data(filename):
    '''
    parameters:
    filename (string): datafile
    
    Returns:
    data (list of lists): each list is a sentence of the text 
    vocab (dictionary): {word: no of times it appears in the text}
    '''
    fin = io.open(filename, 'r', encoding='utf-8')
    data = []
    vocab = defaultdict(lambda:0)
    for line in fin:
        sentence = line.split()
        data.append(sentence)
        for word in sentence:
            vocab[word] += 1
    return data, vocab

# %%
print("load training set..")
print("\n")
train_data, vocab = load_data("train1.txt")
print(train_data[0])
print("\n")
print("how :",vocab['how'])
print("load validation set")
valid_data, _ = load_data("valid1.txt")
# Out:
# load training set..
#
#
# ['<s>', 'my', 'fathers', "don't", 'speak', 'dutch.', '</s>']
#
#
# how : 107
# load validation set

# %%
train_data
# Out:
# [['<s>', 'my', 'fathers', "don't", 'speak', 'dutch.', '</s>'],
#  ['<s>', 'tomorrow', 'is', 'the', 'election.', '</s>'],
#  ['<s>',
#   'he',
#   'worked',
#   'hard',
#   'to',
#   'make',
#   'his',
#   'ideas',
#   'understandable',
#   'at',
#   'the',
#   'meeting.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'going',
#   'to',
#   'stay',
#   'in',
#   'australia',
#   'until',
#   'the',
#   'end',
#   'of',
#   'october.',
#   '</s>'],
#  ['<s>',
#   'john',
#   'took',
#   'the',
#   "lion's",
#   'share',
#   'of',
#   'the',
#   'lottery',
#   'winnings;',
#   'he',
#   'claimed',
#   'it',
#   'was',
#   'his',
#   'idea',
#   'to',
#   'buy',
#   'the',
#   'ticket',
#   'in',
#   'the',
#   'first',
#   'place.',
#   '</s>'],
#  ['<s>', 'some', 'books', 'are', 'on', 'the', 'table.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'they',
#   'were',
#   'getting',
#   'hungry.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'wants',
#   'you',
#   'to',
#   'be',
#   'his',
#   'date',
#   'for',
#   'the',
#   'prom.',
#   '</s>'],
#  ['<s>',
#   'when',
#   'i',
#   'came',
#   'home,',
#   'my',
#   'sister',
#   'was',
#   'playing',
#   'the',
#   'guitar.',
#   '</s>'],
#  ['<s>',
#   "don't",
#   'let',
#   'them',
#   'know',
#   "they're",
#   'being',
#   'watched.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "can't",
#   'have',
#   'done',
#   'that',
#   'by',
#   'themselves.',
#   '</s>'],
#  ['<s>', 'that', 'seems', 'to', 'be', 'the', 'problem.', '</s>'],
#  ['<s>',
#   'tom',
#   'rubbed',
#   'the',
#   'stone',
#   'that',
#   'the',
#   'good',
#   'fairy',
#   'had',
#   'given',
#   'him,',
#   'whereupon',
#   'he',
#   'turned',
#   'into',
#   'a',
#   'squirrel',
#   'and',
#   'could',
#   'escape',
#   'to',
#   'freedom',
#   'through',
#   'the',
#   'bars',
#   'of',
#   'the',
#   'prison',
#   'window',
#   'with',
#   'ease.',
#   '</s>'],
#  ['<s>', 'sami', "didn't", 'wash', 'them.', '</s>'],
#  ['<s>',
#   'this',
#   "isn't",
#   'the',
#   'first',
#   'time',
#   "you've",
#   'been',
#   'late.',
#   '</s>'],
#  ['<s>',
#   'to',
#   'every',
#   'thing',
#   'there',
#   'is',
#   'a',
#   'season,',
#   'and',
#   'a',
#   'time',
#   'to',
#   'every',
#   'purpose.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'may',
#   'be',
#   'able',
#   'to',
#   'answer',
#   'the',
#   'question.',
#   '</s>'],
#  ['<s>', 'what', 'are', 'the', 'chances', 'of', 'that', 'happening?', '</s>'],
#  ['<s>',
#   'tom',
#   'asked',
#   'if',
#   'there',
#   'was',
#   'still',
#   'a',
#   'police',
#   'car',
#   'parked',
#   'outside.',
#   '</s>'],
#  ['<s>', 'tom', 'has', 'been', 'like', 'father', 'to', 'me.', '</s>'],
#  ['<s>',
#   'you',
#   'should',
#   'consider',
#   'the',
#   'problem',
#   'before',
#   'coming',
#   'to',
#   'a',
#   'decision.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'inquired',
#   'whether',
#   'the',
#   'plane',
#   'would',
#   'arrive',
#   'on',
#   'time.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'relationship',
#   'is',
#   'on',
#   'the',
#   'rocks',
#   'and',
#   'the',
#   'couple',
#   'seems',
#   'unable',
#   'to',
#   'find',
#   'ways',
#   'to',
#   'resolve',
#   'their',
#   'differences.',
#   '</s>'],
#  ['<s>',
#   "newton's",
#   'law',
#   'of',
#   'gravity',
#   'is',
#   'a',
#   'mathematical',
#   'description',
#   'of',
#   'the',
#   'way',
#   'bodies',
#   'are',
#   'observed',
#   'to',
#   'attract',
#   'one',
#   'another,',
#   'based',
#   'on',
#   'many',
#   'scientific',
#   'experiments',
#   'and',
#   'observations.',
#   '</s>'],
#  ['<s>', 'they', 'said', 'they', 'need', 'to', 'do', 'that.', '</s>'],
#  ['<s>', 'we', 'managed', 'to', 'swim', 'across', 'the', 'river.', '</s>'],
#  ['<s>',
#   'a',
#   'nation',
#   'creates',
#   'music',
#   '—',
#   'the',
#   'composer',
#   'only',
#   'arranges',
#   'it.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "don't",
#   'know',
#   'whether',
#   'tom',
#   'is',
#   'good',
#   'at',
#   'doing',
#   'that',
#   'or',
#   'not.',
#   '</s>'],
#  ['<s>', 'burn', 'the', 'body.', '</s>'],
#  ['<s>', 'tom', 'and', 'mary', 'have', 'to', 'sing', 'together.', '</s>'],
#  ['<s>',
#   'would',
#   'you',
#   'like',
#   'to',
#   'go',
#   'to',
#   'the',
#   'lake',
#   'with',
#   'us?',
#   '</s>'],
#  ['<s>',
#   'the',
#   'decoration',
#   'of',
#   'the',
#   'church',
#   'is',
#   'beautiful.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "don't",
#   'travel',
#   'together',
#   'anymore.',
#   '</s>'],
#  ['<s>',
#   'in',
#   'the',
#   'time',
#   'of',
#   'the',
#   'romans,',
#   'they',
#   'spoke',
#   'latin.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'aggressive',
#   'salesman',
#   'urged',
#   'me',
#   'to',
#   'sign',
#   'the',
#   'contract',
#   'right',
#   'away.',
#   '</s>'],
#  ['<s>',
#   'being',
#   'there',
#   'i',
#   'feel',
#   'myself',
#   'in',
#   'shelter,',
#   'protected',
#   'by',
#   'the',
#   'love',
#   'of',
#   'all',
#   'my',
#   'dear',
#   'ones.',
#   '</s>'],
#  ['<s>', 'he', 'never', 'knew', 'his', 'father.', '</s>'],
#  ['<s>', 'is', 'there', 'anything', 'you', "don't", 'know?', '</s>'],
#  ['<s>',
#   'in',
#   'seoul,',
#   'for',
#   'example,',
#   'a',
#   'major',
#   'elevated',
#   'thoroughfare',
#   'through',
#   'the',
#   'center',
#   'of',
#   'the',
#   'city',
#   'has',
#   'been',
#   'removed,',
#   'opening',
#   'up',
#   'access',
#   'to',
#   'the',
#   'river',
#   'and',
#   'lowering',
#   'urban',
#   'heat',
#   'in',
#   'the',
#   'area',
#   'by',
#   'at',
#   'least',
#   'half',
#   'a',
#   'degree',
#   'celsius.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "can't",
#   'keep',
#   'up',
#   'with',
#   'the',
#   'recent',
#   'british',
#   'music',
#   'scene.',
#   '</s>'],
#  ['<s>',
#   'he',
#   'looks',
#   'at',
#   'himself',
#   'all',
#   'day',
#   'in',
#   'the',
#   'mirror.',
#   '</s>'],
#  ['<s>', 'he', "didn't", 'come', 'to', 'the', 'last', 'meeting.', '</s>'],
#  ['<s>',
#   'due',
#   'to',
#   'his',
#   'skill',
#   'in',
#   'cutting',
#   'corners,',
#   'he',
#   'managed',
#   'to',
#   'dominate',
#   'the',
#   'senior',
#   'staff.',
#   '</s>'],
#  ['<s>', 'i', 'like', 'the', 'girls.', '</s>'],
#  ['<s>', 'they', 'apologized', 'to', 'their', 'teammates.', '</s>'],
#  ['<s>',
#   'the',
#   'last',
#   'gleam',
#   'of',
#   'the',
#   'sun',
#   'is',
#   'dying',
#   'away.',
#   '</s>'],
#  ['<s>', "i've", 'got', 'lost', 'in', 'the', 'forest.', '</s>'],
#  ['<s>', 'where', 'are', 'the', 'luggage', 'carts?', '</s>'],
#  ['<s>',
#   'if',
#   'the',
#   'weather',
#   'is',
#   'nice,',
#   "i'll",
#   'go',
#   'swimming.',
#   '</s>'],
#  ['<s>',
#   'there',
#   'are',
#   'beautiful',
#   'flowers',
#   'in',
#   'the',
#   'garden.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'showed',
#   'me',
#   'a',
#   'picture',
#   'of',
#   'the',
#   'food',
#   'they',
#   'had',
#   'eaten.',
#   '</s>'],
#  ['<s>', 'i', 'rushed', 'tom', 'to', 'the', 'hospital.', '</s>'],
#  ['<s>',
#   'i',
#   'saw',
#   'tom',
#   'walking',
#   'in',
#   'the',
#   'park',
#   'with',
#   'mary',
#   'last',
#   'monday.',
#   '</s>'],
#  ['<s>', 'tom', "isn't", 'funny', 'either.', '</s>'],
#  ['<s>',
#   'they',
#   'told',
#   'me',
#   'they',
#   'were',
#   'ready',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>', "they're", 'in', 'the', 'science', 'lab.', '</s>'],
#  ['<s>',
#   'i',
#   'wish',
#   'i',
#   'knew',
#   'how',
#   'to',
#   'play',
#   'the',
#   'trombone.',
#   '</s>'],
#  ['<s>', "i'll", 'take', 'the', 'blame', 'for', 'that.', '</s>'],
#  ['<s>', 'tom', 'is', 'the', 'most', 'popular', 'guy', 'in', 'town.', '</s>'],
#  ['<s>',
#   'if',
#   "we're",
#   'not',
#   'careful,',
#   'the',
#   'same',
#   'thing',
#   'will',
#   'happen',
#   'to',
#   'us.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'temperature',
#   'at',
#   'the',
#   'north',
#   'pole',
#   'is',
#   'different',
#   'from',
#   'at',
#   'the',
#   'south',
#   'pole.',
#   '</s>'],
#  ['<s>',
#   "that's",
#   'the',
#   'first',
#   'thing',
#   'i',
#   'ever',
#   'gave',
#   'you.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "don't",
#   'know',
#   'about',
#   'the',
#   'others,',
#   'but',
#   'as',
#   'for',
#   'me,',
#   "i'm",
#   'for',
#   'it.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'told',
#   'you',
#   'not',
#   'to',
#   'play',
#   'your',
#   'cello',
#   'late',
#   'at',
#   'night,',
#   'but',
#   'you',
#   'did',
#   'and',
#   'now',
#   'the',
#   'neighbors',
#   'have',
#   'complained.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'folded',
#   'the',
#   'letter',
#   'and',
#   'put',
#   'it',
#   'into',
#   'the',
#   'envelope.',
#   '</s>'],
#  ['<s>',
#   "what's",
#   'important',
#   "isn't",
#   'the',
#   'goal,',
#   'but',
#   'the',
#   'journey.',
#   '</s>'],
#  ['<s>', 'i', 'found', 'this', 'in', 'the', 'park.', '</s>'],
#  ['<s>', 'tom', "didn't", 'know', 'mary', 'was', "john's", 'mother.', '</s>'],
#  ['<s>',
#   'i',
#   'wonder',
#   'whether',
#   'tom',
#   'and',
#   'mary',
#   'like',
#   'to',
#   'do',
#   'that',
#   'or',
#   'not.',
#   '</s>'],
#  ['<s>', 'sami', 'was', 'trying', 'to', 'sabotage', 'the', 'machine.', '</s>'],
#  ['<s>',
#   'now',
#   'listen',
#   'up',
#   'well,',
#   'these',
#   'might',
#   'well',
#   'be',
#   'my',
#   'last',
#   'words.',
#   '</s>'],
#  ['<s>',
#   'neither',
#   'tom',
#   'nor',
#   'mary',
#   'has',
#   'started',
#   'dating',
#   'again.',
#   '</s>'],
#  ['<s>', 'has', 'anyone', 'seen', 'the', 'paste?', '</s>'],
#  ['<s>', 'he', 'tightened', 'his', 'grip', 'on', 'the', 'rope.', '</s>'],
#  ['<s>',
#   'the',
#   'production',
#   'was',
#   'halted',
#   'after',
#   'a',
#   'horse',
#   'fled',
#   'from',
#   'the',
#   'glue',
#   'factory.',
#   '</s>'],
#  ['<s>', 'she', 'finished', 'the', 'wolf', 'off.', '</s>'],
#  ['<s>', 'oh,', 'there', "isn't", 'much', 'to', 'tell.', '</s>'],
#  ['<s>',
#   'her',
#   'face',
#   'was',
#   'not',
#   'clear',
#   'in',
#   'the',
#   'poor',
#   'light.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'sphinx',
#   'is',
#   'the',
#   'largest',
#   'statue',
#   'in',
#   'egypt.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'asked',
#   'john',
#   'many',
#   'times',
#   'to',
#   'let',
#   'them',
#   'go',
#   'home',
#   'early,',
#   'but',
#   'he',
#   "wouldn't",
#   'let',
#   'them.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'say',
#   'they',
#   "aren't",
#   'giving',
#   'up.',
#   '</s>'],
#  ['<s>', 'gilles', 'crossed', 'the', 'dunes.', '</s>'],
#  ['<s>',
#   'my',
#   'courage',
#   'failed',
#   'me',
#   'at',
#   'the',
#   'crucial',
#   'moment.',
#   '</s>'],
#  ['<s>',
#   'math',
#   'is',
#   'the',
#   'last',
#   'subject',
#   'that',
#   'i',
#   'want',
#   'to',
#   'study.',
#   '</s>'],
#  ['<s>',
#   'he',
#   'represents',
#   'the',
#   'establishment,',
#   'while',
#   'she',
#   'sympathizes',
#   'with',
#   'the',
#   'reformers.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'sooner',
#   'you',
#   'give',
#   'up,',
#   'the',
#   'greater',
#   'the',
#   'benefits.',
#   '</s>'],
#  ['<s>',
#   'my',
#   'friend',
#   'likes',
#   'to',
#   'live',
#   'in',
#   'the',
#   'city,',
#   'but',
#   'his',
#   'wife',
#   'prefers',
#   'to',
#   'live',
#   'in',
#   'their',
#   'little',
#   'cottage',
#   'in',
#   'the',
#   'country.',
#   '</s>'],
#  ['<s>', 'was', 'tom', 'at', 'the', 'funeral?', '</s>'],
#  ['<s>',
#   'my',
#   'mother',
#   'put',
#   'clean',
#   'sheets',
#   'on',
#   'the',
#   'bed.',
#   '</s>'],
#  ['<s>', 'sami', 'went', 'skating', 'with', 'the', 'homies.', '</s>'],
#  ['<s>',
#   'do',
#   'you',
#   'think',
#   'we',
#   'will',
#   'get',
#   'there',
#   'on',
#   'time?',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "don't",
#   'really',
#   'live',
#   'here,',
#   'do',
#   'they?',
#   '</s>'],
#  ['<s>',
#   'the',
#   'idea',
#   'for',
#   'national',
#   'parkways',
#   'began',
#   'in',
#   'the',
#   'early',
#   '1930s,',
#   'during',
#   'the',
#   'great',
#   'depression.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'they',
#   'expect',
#   'to',
#   'be',
#   'doing',
#   'that',
#   'on',
#   'monday.',
#   '</s>'],
#  ['<s>',
#   'mary',
#   'was',
#   'wearing',
#   'an',
#   'apron',
#   'with',
#   'the',
#   'image',
#   'of',
#   'a',
#   'squirrel',
#   'on',
#   'it.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'told',
#   'mary',
#   'that',
#   'she',
#   'did',
#   'the',
#   'right',
#   'thing.',
#   '</s>'],
#  ['<s>', 'i', 'spent', 'a', 'lot', 'of', 'time', 'with', 'them.', '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'the',
#   'one',
#   'who',
#   'told',
#   'me',
#   'not',
#   'to',
#   'do',
#   'that',
#   'anymore.',
#   '</s>'],
#  ['<s>', 'philosophy', 'is', 'the', 'love', 'of', 'wisdom.', '</s>'],
#  ['<s>', "we're", 'not', 'going', 'in', 'there.', '</s>'],
#  ['<s>',
#   'tom',
#   'told',
#   'mary',
#   'that',
#   'he',
#   'could',
#   'predict',
#   'the',
#   'future.',
#   '</s>'],
#  ['<s>',
#   'one',
#   'of',
#   "tom's",
#   'teachers',
#   'asked',
#   'tom',
#   'to',
#   'stay',
#   'after',
#   'school',
#   'to',
#   'help',
#   'clean',
#   'the',
#   'classroom.',
#   '</s>'],
#  ['<s>', 'tom', 'laid', 'his', 'racket', 'on', 'the', 'ground.', '</s>'],
#  ['<s>', 'i', 'was', 'hardly', 'able', 'to', 'see', 'them.', '</s>'],
#  ['<s>',
#   'those',
#   'were',
#   'some',
#   'seriously',
#   'smooth',
#   'moves',
#   'out',
#   'there',
#   'on',
#   'the',
#   'dance',
#   'floor!',
#   '</s>'],
#  ['<s>',
#   'the',
#   'surface',
#   'of',
#   'the',
#   'peculiar',
#   'object',
#   'is',
#   'fairly',
#   'rough.',
#   '</s>'],
#  ['<s>',
#   'beauty',
#   "doesn't",
#   'say',
#   'anything',
#   'about',
#   'the',
#   'character',
#   'of',
#   'a',
#   'person.',
#   '</s>'],
#  ['<s>', 'my', 'father', 'died', 'of', 'cancer.', '</s>'],
#  ['<s>', "i'll", 'be', 'with', 'you', 'the', 'whole', 'time.', '</s>'],
#  ['<s>',
#   'they',
#   'need',
#   'help',
#   'to',
#   'understand',
#   'their',
#   'office',
#   'equipment.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'peeked',
#   'in',
#   'the',
#   'box',
#   'to',
#   'see',
#   'what',
#   'was',
#   'inside.',
#   '</s>'],
#  ['<s>',
#   '"what\'s',
#   'the',
#   'matter?"',
#   '"i',
#   "can't",
#   'find',
#   'my',
#   'keys."',
#   '"which',
#   'ones?"',
#   '"my',
#   'bicycle',
#   'ones."',
#   '</s>'],
#  ['<s>',
#   'i',
#   'talked',
#   'a',
#   'little',
#   'to',
#   'aki',
#   'about',
#   'clothes.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'keeps',
#   'an',
#   'eagle',
#   'feather',
#   'as',
#   'a',
#   'good-luck',
#   'charm.',
#   '</s>'],
#  ['<s>',
#   'when',
#   'the',
#   'input',
#   'exceeds',
#   'a',
#   'certain',
#   'threshold,',
#   'an',
#   'output',
#   'signal',
#   'is',
#   'instantaneously',
#   'released.',
#   '</s>'],
#  ['<s>',
#   'your',
#   'father',
#   'works',
#   'for',
#   'a',
#   'bank,',
#   "doesn't",
#   'he?',
#   '</s>'],
#  ['<s>', 'tom', 'is', 'on', 'the', 'wrestling', 'team.', '</s>'],
#  ['<s>', 'why', 'would', 'there', 'be', 'trouble?', '</s>'],
#  ['<s>', 'i', "can't", 'go', 'to', 'australia,', 'either.', '</s>'],
#  ['<s>', 'even', 'they', 'themselves', 'refused', 'to', 'do', 'it.', '</s>'],
#  ['<s>', 'i', 'had', 'my', 'wallet', 'stolen', 'on', 'the', 'bus.', '</s>'],
#  ['<s>',
#   'tomorrow,',
#   "i've",
#   'got',
#   'an',
#   'important',
#   'mission',
#   'first',
#   'thing',
#   'in',
#   'the',
#   'morning.',
#   'i',
#   "shouldn't",
#   'be',
#   'wasting',
#   'my',
#   'time',
#   'with',
#   'this.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'promised',
#   'to',
#   'do',
#   'everything',
#   'they',
#   'could',
#   'to',
#   'help',
#   'me.',
#   '</s>'],
#  ['<s>',
#   'they',
#   'told',
#   'me',
#   'that',
#   'they',
#   'want',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>',
#   'mary',
#   'neatly',
#   'folded',
#   'her',
#   'clothes',
#   'and',
#   'placed',
#   'them',
#   'in',
#   'her',
#   'dresser',
#   'drawers.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "didn't",
#   'tell',
#   'him',
#   'the',
#   'truth',
#   'because',
#   'i',
#   'was',
#   'afraid',
#   'of',
#   'hurting',
#   'his',
#   'feelings.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'know',
#   'tom',
#   'is',
#   'afraid',
#   'to',
#   'walk',
#   'through',
#   'the',
#   'woods',
#   'alone.',
#   '</s>'],
#  ['<s>', 'they', 'say', 'that', 'they', 'plan', 'on', 'going.', '</s>'],
#  ['<s>',
#   'rapunzel',
#   'had',
#   'magnificent',
#   'long',
#   'hair,',
#   'fine',
#   'as',
#   'spun',
#   'gold,',
#   'and',
#   'when',
#   'she',
#   'heard',
#   'the',
#   'voice',
#   'of',
#   'the',
#   'enchantress',
#   'she',
#   'unfastened',
#   'her',
#   'braided',
#   'tresses,',
#   'wound',
#   'them',
#   'round',
#   'one',
#   'of',
#   'the',
#   'hooks',
#   'of',
#   'the',
#   'window',
#   'above,',
#   'and',
#   'then',
#   'the',
#   'hair',
#   'fell',
#   'twenty',
#   'ells',
#   'down,',
#   'and',
#   'the',
#   'enchantress',
#   'climbed',
#   'up',
#   'by',
#   'it.',
#   '</s>'],
#  ['<s>', 'tom', 'and', 'mary', 'sat', 'close', 'to', 'the', 'fire.', '</s>'],
#  ['<s>', 'my', 'grandmother', 'passed', 'away', 'last', 'year.', '</s>'],
#  ['<s>',
#   'the',
#   'law',
#   'does',
#   'not',
#   'apply',
#   'to',
#   'the',
#   'powerful.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "didn't",
#   'think',
#   'we',
#   'should',
#   'do',
#   'that',
#   'the',
#   'way',
#   'tom',
#   'told',
#   'us',
#   'to.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'want',
#   'to',
#   'spend',
#   'the',
#   'whole',
#   'day',
#   'with',
#   'you.',
#   '</s>'],
#  ['<s>',
#   'to',
#   'tell',
#   'you',
#   'the',
#   'truth,',
#   'my',
#   'biggest',
#   'worry',
#   'is',
#   'what',
#   'tom',
#   'will',
#   'do',
#   'if',
#   'he',
#   'finds',
#   'out',
#   'that',
#   'mary',
#   'has',
#   'been',
#   'killed.',
#   '</s>'],
#  ['<s>', "that's", 'because', "they're", 'vicious.', '</s>'],
#  ['<s>',
#   'the',
#   'ldp',
#   'brought',
#   'out',
#   'a',
#   'bill',
#   'to',
#   'raise',
#   'taxes,',
#   'but',
#   'they',
#   'met',
#   'with',
#   'such',
#   'violent',
#   'opposition',
#   'that',
#   'they',
#   'backed',
#   'down.',
#   '</s>'],
#  ['<s>', "don't", 'bother', 'asking', 'me', 'to', 'go.', '</s>'],
#  ['<s>', 'they', "don't", 'speak', 'french,', 'do', 'they?', '</s>'],
#  ['<s>', 'i', 'wish', 'tom', "wouldn't", 'keep', 'bothering', 'me.', '</s>'],
#  ['<s>',
#   "it's",
#   'no',
#   'good',
#   'his',
#   'trying',
#   'to',
#   'find',
#   'the',
#   'true',
#   'reason.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'only',
#   'need',
#   'another',
#   'few',
#   'days',
#   'to',
#   'make',
#   'things',
#   'right.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'teachers',
#   'ate',
#   'lunch',
#   'with',
#   'the',
#   'students.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'saw',
#   'mary',
#   'walk',
#   'in',
#   'and',
#   'take',
#   'a',
#   'seat',
#   'in',
#   'the',
#   'back',
#   'of',
#   'the',
#   'room.',
#   '</s>'],
#  ['<s>',
#   'obviously,',
#   'the',
#   'server',
#   'load',
#   'will',
#   'increase',
#   'as',
#   'a',
#   'result.',
#   '</s>'],
#  ['<s>', 'sami', 'lost', 'his', 'way', 'in', 'the', 'jungle.', '</s>'],
#  ['<s>',
#   'i',
#   "couldn't",
#   'decide',
#   'which',
#   'shirt',
#   'to',
#   'buy,',
#   'so',
#   'i',
#   "didn't",
#   'buy',
#   'either.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'need',
#   'to',
#   'talk',
#   'to',
#   'tom',
#   'and',
#   'mary',
#   'about',
#   'what',
#   'they',
#   'said',
#   "they'd",
#   'do.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'say',
#   "they're",
#   'not',
#   'planning',
#   'on',
#   'going',
#   'anymore.',
#   '</s>'],
#  ['<s>', 'i', 'accommodated', 'him', 'for', 'the', 'night.', '</s>'],
#  ['<s>',
#   'a',
#   'funny',
#   'thing',
#   'happened',
#   'to',
#   'me',
#   'on',
#   'the',
#   'way',
#   'here',
#   'today.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'will',
#   'go',
#   'there',
#   'on',
#   'foot',
#   'or',
#   'by',
#   'bicycle',
#   'next',
#   'time.',
#   '</s>'],
#  ['<s>',
#   'many',
#   'people',
#   'think',
#   'that',
#   'sharks',
#   'are',
#   'the',
#   'most',
#   'dangerous',
#   'fish',
#   'in',
#   'the',
#   'ocean.',
#   '</s>'],
#  ['<s>',
#   'they',
#   'said',
#   'that',
#   'they',
#   'thought',
#   'i',
#   'was',
#   'cute.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'hope',
#   'that',
#   'i',
#   'can',
#   'visit',
#   'australia',
#   'in',
#   'the',
#   'near',
#   'future.',
#   '</s>'],
#  ['<s>',
#   'they',
#   'are',
#   'in',
#   'trouble.',
#   'can',
#   'you',
#   'help',
#   'them?',
#   '</s>'],
#  ['<s>', 'are', 'you', 'going', 'to', 'hurt', 'them?', '</s>'],
#  ['<s>',
#   'i',
#   "don't",
#   'want',
#   'to',
#   'acquaint',
#   'you',
#   'my',
#   'father.',
#   '</s>'],
#  ['<s>',
#   'he',
#   'always',
#   'leaves',
#   'the',
#   'window',
#   'open',
#   'when',
#   'he',
#   'sleeps.',
#   '</s>'],
#  ['<s>', 'i', 'love', 'you', 'the', 'way', 'you', 'are.', '</s>'],
#  ['<s>',
#   'age',
#   'is',
#   'not',
#   'important,',
#   'unless',
#   'you',
#   'are',
#   'either',
#   'cheese',
#   'or',
#   'wine.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'say',
#   'they',
#   "aren't",
#   'planning',
#   'to',
#   'go',
#   'anywhere.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "didn't",
#   'actually',
#   'do',
#   'what',
#   'they',
#   'said',
#   "they'd",
#   'do.',
#   '</s>'],
#  ['<s>', 'tom', 'is', 'swimming', 'in', 'the', 'river.', '</s>'],
#  ['<s>',
#   'you',
#   'might',
#   'want',
#   'to',
#   'try',
#   'studying',
#   'in',
#   'the',
#   'library.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'space',
#   'hotel',
#   'had',
#   'enormous',
#   'bay',
#   'windows',
#   'overlooking',
#   'the',
#   'rainbow',
#   'stripes',
#   'of',
#   'jupiter',
#   'below.',
#   '</s>'],
#  ['<s>', 'we', 'offered', 'him', 'the', 'house', 'for', '$300,000.', '</s>'],
#  ['<s>',
#   "it's",
#   'not',
#   'all',
#   'that',
#   'uncommon',
#   'for',
#   'people',
#   'to',
#   'live',
#   'past',
#   'the',
#   'age',
#   'of',
#   'ninety.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'attributed',
#   'the',
#   'delay',
#   'in',
#   'delivery',
#   'to',
#   'a',
#   'traffic',
#   'jam.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'byzantines',
#   'massacred',
#   'most',
#   'of',
#   'the',
#   'jewish',
#   'population',
#   'of',
#   'palestine.',
#   '</s>'],
#  ['<s>',
#   'there',
#   'are',
#   'swift-flowing',
#   'rivers',
#   'which',
#   'dash',
#   'through',
#   'jagged',
#   'cañons;',
#   'and',
#   'there',
#   'are',
#   'enormous',
#   'plains,',
#   'which',
#   'in',
#   'winter',
#   'are',
#   'white',
#   'with',
#   'snow,',
#   'and',
#   'in',
#   'summer',
#   'are',
#   'grey',
#   'with',
#   'saline',
#   'alkali',
#   'dust.',
#   '</s>'],
#  ['<s>',
#   'body',
#   'fossils',
#   'are',
#   'the',
#   'preserved',
#   'remains',
#   'of',
#   'ancient',
#   'life,',
#   'such',
#   'as',
#   'bones,',
#   'teeth,',
#   'wood,',
#   'and',
#   'shells.',
#   '</s>'],
#  ['<s>',
#   'lady',
#   'ashton',
#   'became',
#   'much',
#   'alarmed',
#   'and',
#   'consulted',
#   'the',
#   'family',
#   'physicians.',
#   '</s>'],
#  ['<s>', 'my', 'grandmother', 'can', 'ride', 'a', 'motorcycle.', '</s>'],
#  ['<s>', "don't", 'speak', 'all', 'at', 'the', 'same', 'time.', '</s>'],
#  ['<s>', 'as', 'is', 'often', 'the', 'case,', "she's", 'not', 'here.', '</s>'],
#  ['<s>',
#   'tom',
#   'was',
#   'stealing',
#   'money',
#   'for',
#   'the',
#   'last',
#   'two',
#   'years,',
#   'and',
#   'mary',
#   'knew',
#   'it',
#   'all',
#   'the',
#   'time.',
#   '</s>'],
#  ['<s>',
#   'all',
#   'the',
#   'boys',
#   'were',
#   'whistling',
#   'and',
#   'cheering.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'am',
#   'your',
#   'mother.',
#   'i',
#   'am',
#   'to',
#   'be',
#   'obeyed',
#   '-',
#   'not',
#   'questioned.',
#   '</s>'],
#  ['<s>', 'when', 'is', 'the', 'last', 'time', 'you', 'showered?', '</s>'],
#  ['<s>',
#   'we',
#   'have',
#   'some',
#   'doubt',
#   'as',
#   'to',
#   'whether',
#   'he',
#   'has',
#   'chosen',
#   'the',
#   'right',
#   'course.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'figured',
#   'that',
#   'tom',
#   "wouldn't",
#   'know',
#   'the',
#   'answer.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "won't",
#   'give',
#   'my',
#   'test',
#   'back',
#   'to',
#   'the',
#   'teacher.',
#   '</s>'],
#  ['<s>',
#   'thomas',
#   'edison',
#   'invented',
#   'the',
#   'electric',
#   'lightbulb.',
#   '</s>'],
#  ['<s>', 'tom', 'notified', 'the', 'police.', '</s>'],
#  ['<s>', 'is', 'there', 'a', 'place', 'for', 'tom?', '</s>'],
#  ['<s>',
#   'what',
#   'tom',
#   'likes',
#   'most',
#   'is',
#   'whiskey',
#   'on',
#   'the',
#   'rocks.',
#   '</s>'],
#  ['<s>',
#   'would',
#   'it',
#   'be',
#   'ok',
#   'to',
#   'ask',
#   'tom',
#   'to',
#   'sing',
#   'another',
#   'song?',
#   '</s>'],
#  ['<s>', 'tom', 'has', 'the', 'right', 'to', 'vote.', '</s>'],
#  ['<s>',
#   'do',
#   'i',
#   'or',
#   "don't",
#   'i',
#   'want',
#   'the',
#   'extra',
#   'responsibility',
#   'of',
#   'maintaining',
#   'a',
#   'beard?',
#   '</s>'],
#  ['<s>', 'are', 'all', 'the', 'bars', 'shut?', '</s>'],
#  ['<s>', 'my', 'little', 'brother', 'can', 'read', 'english.', '</s>'],
#  ['<s>', "i'm", 'not', 'working', 'for', 'them.', '</s>'],
#  ['<s>',
#   'sami',
#   'and',
#   "layla's",
#   'relationship',
#   'problems',
#   'started',
#   'to',
#   'create',
#   'some',
#   'tension',
#   'at',
#   'the',
#   'office.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'are',
#   'doing',
#   'exactly',
#   'what',
#   'john',
#   'asked',
#   'them',
#   'to',
#   'do.',
#   '</s>'],
#  ['<s>',
#   'do',
#   'you',
#   'remember',
#   'when',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'they',
#   'were',
#   'planning',
#   'to',
#   'do',
#   'that?',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'are',
#   'going',
#   'to',
#   'do',
#   'that',
#   'as',
#   'soon',
#   'as',
#   'they',
#   'can.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   "isn't",
#   'the',
#   'only',
#   'one',
#   'here',
#   'who',
#   'can',
#   'play',
#   'the',
#   'oboe.',
#   '</s>'],
#  ['<s>',
#   'neither',
#   'tom',
#   'nor',
#   'mary',
#   'has',
#   'been',
#   'friendly',
#   'to',
#   'me.',
#   '</s>'],
#  ['<s>',
#   'most',
#   'students',
#   'are',
#   'preparing',
#   'for',
#   'the',
#   'final',
#   'exams.',
#   '</s>'],
#  ['<s>', 'please', 'pass', 'me', 'the', 'salt.', '</s>'],
#  ['<s>', 'tom', 'is', 'looking', 'at', 'the', 'floor.', '</s>'],
#  ['<s>', 'your', 'arrival', 'changed', 'the', 'situation.', '</s>'],
#  ['<s>', 'they', 'swore', 'that', "they'd", 'quit', 'smoking.', '</s>'],
#  ['<s>', 'is', 'there', 'another', 'remedy?', '</s>'],
#  ['<s>',
#   'this',
#   'is',
#   'the',
#   'first',
#   'time',
#   "i've",
#   'ever',
#   'shouted',
#   'at',
#   'taninna.',
#   '</s>'],
#  ['<s>',
#   'sami',
#   'and',
#   'layla',
#   'live',
#   'on',
#   'the',
#   'same',
#   'island.',
#   '</s>'],
#  ['<s>', 'stick', 'another', 'stamp', 'on', 'the', 'envelope.', '</s>'],
#  ['<s>',
#   'japan,',
#   'for',
#   'the',
#   'most',
#   'part,',
#   'is',
#   'a',
#   'lovely',
#   'place',
#   'to',
#   'live',
#   'in.',
#   '</s>'],
#  ['<s>',
#   'who',
#   'are',
#   'you',
#   'calling',
#   'sweet-n-sour?!',
#   'at',
#   'the',
#   'very',
#   'least',
#   'i',
#   'certainly',
#   "don't",
#   'remember',
#   'being',
#   'sweet!',
#   '</s>'],
#  ['<s>',
#   'the',
#   'new',
#   'situation',
#   'makes',
#   'it',
#   'harder',
#   'for',
#   'the',
#   'indian',
#   'government',
#   'to',
#   'combat',
#   'the',
#   'spread',
#   'of',
#   'the',
#   'aids',
#   'virus.',
#   '</s>'],
#  ['<s>', "i'm", 'not', 'ready', 'to', 'be', 'a', 'mother.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'wondered',
#   'why',
#   "they'd",
#   'never',
#   'seen',
#   'john',
#   'here',
#   'before.',
#   '</s>'],
#  ['<s>',
#   'when',
#   'i',
#   'say',
#   'that',
#   'this',
#   'spider',
#   'is',
#   'harmless,',
#   'i',
#   "don't",
#   'mean',
#   'that',
#   'you',
#   'can',
#   'catch',
#   'it',
#   'with',
#   'your',
#   'hands',
#   'and',
#   'handle',
#   'it',
#   'as',
#   'you',
#   'like.',
#   'big',
#   'spiders',
#   "don't",
#   'attack',
#   'people',
#   'unless',
#   'they',
#   'are',
#   'provoked,',
#   'and',
#   'they',
#   'should',
#   'not',
#   'be',
#   'taken',
#   'for',
#   'toys.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'policemen',
#   'beat',
#   'the',
#   'bushes',
#   'all',
#   'day',
#   'to',
#   'find',
#   'a',
#   'lost',
#   'child.',
#   '</s>'],
#  ['<s>',
#   'sami',
#   'said',
#   'something',
#   'along',
#   'the',
#   'lines:',
#   '"hey,',
#   'how',
#   'are',
#   'you?"',
#   '</s>'],
#  ['<s>', 'i', "can't", 'tell', 'one', 'twin', 'from', 'the', 'other.', '</s>'],
#  ['<s>',
#   'tomorrow,',
#   "i'm",
#   'going',
#   'to',
#   'study',
#   'at',
#   'the',
#   'library.',
#   '</s>'],
#  ['<s>', 'tom', 'is', 'the', 'one', 'who', 'built', 'this', 'house.', '</s>'],
#  ['<s>', 'when', 'do', 'the', 'examinations', 'start?', '</s>'],
#  ['<s>',
#   'individual',
#   'atoms',
#   'can',
#   'combine',
#   'with',
#   'other',
#   'atoms',
#   'to',
#   'form',
#   'molecules.',
#   '</s>'],
#  ['<s>', 'for', 'them,', 'it', 'was', 'the', 'end.', '</s>'],
#  ['<s>',
#   'tom',
#   'blew',
#   'up',
#   'the',
#   'balloons',
#   'and',
#   'gave',
#   'them',
#   'to',
#   'his',
#   'children.',
#   '</s>'],
#  ['<s>', 'sami', 'left', 'the', 'club', 'in', 'his', 'car.', '</s>'],
#  ['<s>',
#   'in',
#   'a',
#   'liquid',
#   'rocket,',
#   'the',
#   'propellants,',
#   'the',
#   'fuel',
#   'and',
#   'the',
#   'oxidizer,',
#   'are',
#   'stored',
#   'separately',
#   'as',
#   'liquids',
#   'and',
#   'are',
#   'pumped',
#   'into',
#   'the',
#   'combustion',
#   'chamber',
#   'of',
#   'the',
#   'nozzle',
#   'where',
#   'burning',
#   'occurs.',
#   '</s>'],
#  ['<s>',
#   'you',
#   'should',
#   'do',
#   'that',
#   'now',
#   'while',
#   'you',
#   'have',
#   'the',
#   'chance.',
#   '</s>'],
#  ['<s>',
#   'der',
#   'butler',
#   'brachte',
#   'mir',
#   'meinen',
#   'kaffee',
#   'in',
#   'die',
#   'bibliothek.',
#   '</s>'],
#  ['<s>',
#   'he',
#   'is',
#   'without',
#   'doubt',
#   'one',
#   'of',
#   'the',
#   'most',
#   'successful',
#   'businessmen',
#   'in',
#   'japan.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'took',
#   'the',
#   'job',
#   'that',
#   'mary',
#   'offered',
#   'him.',
#   '</s>'],
#  ['<s>',
#   'it',
#   'is',
#   'doubtful',
#   'whether',
#   'she',
#   'will',
#   'come',
#   'on',
#   'time.',
#   '</s>'],
#  ['<s>', 'tom', 'left', 'through', 'the', 'front', 'door.', '</s>'],
#  ['<s>',
#   'dan',
#   'saw',
#   'linda',
#   'crying',
#   'near',
#   'the',
#   'pay',
#   'phone.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'said',
#   'that',
#   'he',
#   'was',
#   'very',
#   'glad',
#   'that',
#   'we',
#   'could',
#   'be',
#   'there.',
#   '</s>'],
#  ['<s>', 'i', 'found', 'the', 'keys', 'i', 'thought', "i'd", 'lost.', '</s>'],
#  ['<s>', 'tom', 'quickly', 'scanned', 'the', 'manuscript.', '</s>'],
#  ['<s>',
#   'tom',
#   'has',
#   'an',
#   'appointment',
#   'with',
#   'the',
#   'doctor',
#   'on',
#   'friday.',
#   '</s>'],
#  ['<s>',
#   "i'm",
#   'assuming',
#   'the',
#   'gunshot',
#   'i',
#   'heard',
#   'was',
#   'the',
#   'one',
#   'that',
#   'killed',
#   'tom.',
#   '</s>'],
#  ['<s>', 'they', 'say', 'they', 'were', 'abducted', 'by', 'aliens.', '</s>'],
#  ['<s>',
#   'tom',
#   'had',
#   'a',
#   'raspy',
#   'cough,',
#   'the',
#   'result',
#   'of',
#   'years',
#   'of',
#   'heavy',
#   'smoking.',
#   '</s>'],
#  ['<s>', 'did', 'you', 'grade', 'the', 'tests?', '</s>'],
#  ['<s>',
#   'tom',
#   'said',
#   'he',
#   "didn't",
#   'have',
#   'the',
#   'time',
#   'or',
#   'the',
#   'inclination',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>', 'is', 'anyone', 'out', 'there', 'with', 'her?', '</s>'],
#  ['<s>',
#   'i',
#   'have',
#   'the',
#   'impression',
#   'that',
#   'she',
#   'has',
#   'fallen',
#   'in',
#   'love',
#   'with',
#   'me.',
#   'what',
#   'should',
#   'i',
#   'do?',
#   '</s>'],
#  ['<s>',
#   'why',
#   'did',
#   'the',
#   'lawyer',
#   'lose',
#   'in',
#   'the',
#   'argument?',
#   '</s>'],
#  ['<s>', 'call', 'your', 'mother.', '</s>'],
#  ['<s>',
#   "wouldn't",
#   'you',
#   'rather',
#   'watch',
#   'the',
#   'baseball',
#   'game?',
#   '</s>'],
#  ['<s>', 'bill', 'clinton', 'denied', 'the', 'accusation.', '</s>'],
#  ['<s>',
#   'the',
#   'cold',
#   'war',
#   'may',
#   'have',
#   'ended,',
#   'but',
#   'the',
#   'fear',
#   'of',
#   'war',
#   'has',
#   'not',
#   'yet',
#   'been',
#   'removed',
#   'from',
#   'the',
#   'minds',
#   'of',
#   'men.',
#   '</s>'],
#  ['<s>',
#   'compared',
#   'with',
#   'his',
#   'brother,',
#   'he',
#   'is',
#   'not',
#   'so',
#   'intelligent.',
#   '</s>'],
#  ['<s>', 'they', 'accomplished', 'their', 'homework.', '</s>'],
#  ['<s>',
#   'a',
#   'poet',
#   'looks',
#   'at',
#   'the',
#   'world',
#   'as',
#   'a',
#   'man',
#   'looks',
#   'at',
#   'a',
#   'woman.',
#   '</s>'],
#  ['<s>',
#   'neither',
#   'tom',
#   'nor',
#   'mary',
#   'has',
#   'been',
#   'living',
#   'alone',
#   'for',
#   'very',
#   'long.',
#   '</s>'],
#  ['<s>',
#   'there',
#   'are',
#   'many',
#   'ideological',
#   'similarities',
#   'between',
#   'parties',
#   'at',
#   'the',
#   'extreme',
#   'ends',
#   'of',
#   'the',
#   'political',
#   'spectrum.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'main',
#   'shops',
#   'are',
#   'in',
#   'the',
#   'city',
#   'centre.',
#   '</s>'],
#  ['<s>', 'i', 'heard', 'they', 'caught', 'them.', '</s>'],
#  ['<s>',
#   'this',
#   'generation',
#   'of',
#   'online',
#   'daters,',
#   'far',
#   'more',
#   'native',
#   'to',
#   'the',
#   'internet,',
#   'are',
#   'a',
#   'lot',
#   'less',
#   'awkward',
#   'than',
#   'the',
#   'first',
#   'generation.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'told',
#   'the',
#   'story',
#   'that',
#   'my',
#   'mom',
#   'told',
#   'me',
#   'to',
#   'my',
#   'daughter.',
#   '</s>'],
#  ['<s>', 'he', 'substituted', 'for', 'his', 'father.', '</s>'],
#  ['<s>',
#   'i',
#   'should',
#   'like',
#   'to',
#   'see',
#   'the',
#   'trees',
#   'from',
#   'which',
#   'you',
#   'picked',
#   'these',
#   'apples.',
#   '</s>'],
#  ['<s>',
#   'it',
#   'does',
#   'not',
#   'become',
#   'us',
#   'to',
#   'be',
#   'idle',
#   'or',
#   'chat',
#   'away',
#   'here',
#   'while',
#   'the',
#   'master',
#   'is',
#   'expected.',
#   '</s>'],
#  ['<s>', 'all', 'the', 'hot', 'guys', 'are', 'already', 'taken.', '</s>'],
#  ['<s>',
#   'if',
#   'this',
#   'is',
#   'your',
#   'knife,',
#   'then',
#   'i',
#   'have',
#   'lost',
#   'mine.',
#   '</s>'],
#  ['<s>', 'i', 'want', 'to', 'handle', 'the', 'problem', 'myself.', '</s>'],
#  ['<s>',
#   'lead',
#   'author',
#   'andrew',
#   'shepherd',
#   'of',
#   'the',
#   'university',
#   'of',
#   'leeds',
#   'in',
#   'england',
#   'said',
#   'it',
#   'is',
#   'possible',
#   'that',
#   "antarctica's",
#   'melting',
#   'alone',
#   'could',
#   'add',
#   '16',
#   'centimeters',
#   'to',
#   'sea',
#   'level',
#   'rise',
#   'across',
#   'the',
#   'globe',
#   'by',
#   'the',
#   'end',
#   'of',
#   'this',
#   'century.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "didn't",
#   'think',
#   'john',
#   'would',
#   'allow',
#   'them',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>', 'tom', 'had', 'dinner', 'with', 'his', 'grandfather.', '</s>'],
#  ['<s>',
#   'open',
#   'the',
#   'window',
#   'and',
#   'let',
#   'in',
#   'some',
#   'fresh',
#   'air.',
#   '</s>'],
#  ['<s>',
#   'it',
#   'was',
#   'foggy,',
#   'so',
#   'it',
#   'was',
#   'hard',
#   'to',
#   'make',
#   'out',
#   'the',
#   'figures',
#   'of',
#   'people',
#   'walking.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'planning',
#   'to',
#   'meet',
#   'his',
#   'friends',
#   'at',
#   'the',
#   'local',
#   'pub.',
#   '</s>'],
#  ['<s>', 'tom', 'and', 'i', "don't", 'trust', 'each', 'other.', '</s>'],
#  ['<s>',
#   'tom',
#   'was',
#   'the',
#   'last',
#   'one',
#   'to',
#   'leave',
#   'the',
#   'office.',
#   '</s>'],
#  ['<s>', 'layla', 'put', 'the', 'money', 'in', 'a', 'shoe', 'box.', '</s>'],
#  ['<s>',
#   'she',
#   'paid',
#   'a',
#   '€900',
#   'deposit',
#   'for',
#   'the',
#   'appartment.',
#   '</s>'],
#  ['<s>',
#   "i'm",
#   'teaching',
#   'basic',
#   'participial',
#   'constructions',
#   'now,',
#   'but,',
#   'with',
#   'regard',
#   'to',
#   'those',
#   'below,',
#   'what',
#   'different',
#   'ways',
#   'of',
#   'translating',
#   'them',
#   'would',
#   'everybody',
#   'use?',
#   '</s>'],
#  ['<s>',
#   'we',
#   'can',
#   'handle',
#   'these',
#   'troubles,',
#   'we',
#   'are',
#   'used',
#   'to',
#   'them.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'alleviation',
#   'of',
#   'poverty',
#   'is',
#   'an',
#   'issue',
#   'which',
#   'confronts',
#   'governments',
#   'around',
#   'the',
#   'world.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'feel',
#   'like',
#   "i'm",
#   'seeing',
#   'the',
#   'light',
#   'for',
#   'the',
#   'first',
#   'time.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'they',
#   'intend',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>', 'i', 'remember', 'that', 'i', 'gave', 'him', 'the', 'key.', '</s>'],
#  ['<s>', 'tom', 'looked', 'in', 'through', 'the', 'window.', '</s>'],
#  ['<s>',
#   'who',
#   'do',
#   'you',
#   'usually',
#   'go',
#   'to',
#   'the',
#   'movies',
#   'with?',
#   '</s>'],
#  ['<s>', 'they', "didn't", 'specify', 'the', 'year.', '</s>'],
#  ['<s>',
#   'well,',
#   'i',
#   'always',
#   'have',
#   'time',
#   'for',
#   'a',
#   'friend.',
#   'they',
#   'know',
#   'they',
#   'can',
#   'count',
#   'on',
#   'me.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'seven',
#   'seas',
#   'include',
#   'the',
#   'arctic,',
#   'north',
#   'atlantic,',
#   'south',
#   'atlantic,',
#   'north',
#   'pacific,',
#   'south',
#   'pacific,',
#   'indian,',
#   'and',
#   'southern',
#   'oceans.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'hardly',
#   'ever',
#   'buy',
#   'anything',
#   'other',
#   'than',
#   'food.',
#   '</s>'],
#  ['<s>',
#   '"we',
#   'are',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'a',
#   'war",',
#   'said',
#   'the',
#   'president.',
#   '</s>'],
#  ['<s>', "i've", 'been', 'helping', 'them.', '</s>'],
#  ['<s>', 'you', 'can', 'feel', 'safe', 'here', 'in', 'the', 'house.', '</s>'],
#  ['<s>', 'what', 'did', 'the', 'kidnapper', 'look', 'like?', '</s>'],
#  ['<s>',
#   'i',
#   'wonder',
#   'what',
#   'made',
#   'tom',
#   'think',
#   'that',
#   'mary',
#   'was',
#   'the',
#   'one',
#   'who',
#   'did',
#   'that?',
#   '</s>'],
#  ['<s>',
#   'gaslighting',
#   'takes',
#   'its',
#   'name',
#   'from',
#   'the',
#   '1938',
#   'patrick',
#   'hamilton',
#   'play',
#   "'gas",
#   "light'.",
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'they',
#   "couldn't",
#   'believe',
#   'anybody.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'went',
#   'into',
#   'the',
#   'town',
#   'in',
#   'search',
#   'of',
#   'a',
#   'good',
#   'restaurant.',
#   '</s>'],
#  ['<s>', "they'll", 'start', 'their', 'new', 'jobs', 'on', 'monday.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "don't",
#   'see',
#   'why',
#   'they',
#   'should',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'the',
#   'only',
#   'one',
#   'in',
#   'our',
#   'family',
#   'who',
#   "doesn't",
#   'have',
#   'a',
#   "driver's",
#   'license.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'john',
#   'both',
#   'said',
#   'they',
#   'wished',
#   'they',
#   "hadn't",
#   'let',
#   'mary',
#   'kiss',
#   'them.',
#   '</s>'],
#  ['<s>', 'have', 'you', 'fed', 'the', 'dog', 'this', 'morning?', '</s>'],
#  ['<s>',
#   'i',
#   'told',
#   'tom',
#   'i',
#   "didn't",
#   'know',
#   'any',
#   'other',
#   'way',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>', 'other', 'than', 'that,', "i've", 'been', 'doing', 'well.', '</s>'],
#  ['<s>',
#   'limit',
#   'your',
#   'remarks',
#   'to',
#   'the',
#   'matter',
#   'we',
#   'are',
#   'discussing.',
#   '</s>'],
#  ['<s>', 'he', 'knows', 'the', 'secret.', '</s>'],
#  ['<s>',
#   'do',
#   'you',
#   'want',
#   'to',
#   'walk',
#   'to',
#   'the',
#   'station',
#   'with',
#   'me?',
#   '</s>'],
#  ['<s>', 'i', 'paid', 'for', 'them.', '</s>'],
#  ['<s>',
#   "tom's",
#   'teacher',
#   'suspected',
#   'tom',
#   'had',
#   'cheated',
#   'on',
#   'the',
#   'test.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'said',
#   'that',
#   'there',
#   'was',
#   'a',
#   'party',
#   'at',
#   'your',
#   'place',
#   'tonight.',
#   '</s>'],
#  ['<s>',
#   'she',
#   'closed',
#   'the',
#   'door',
#   'and',
#   'went',
#   'to',
#   'the',
#   'first',
#   'floor.',
#   '</s>'],
#  ['<s>', 'is', 'anybody', 'on', 'the', 'line?', '</s>'],
#  ['<s>',
#   'my',
#   "grandfather's",
#   'painting',
#   'is',
#   'on',
#   'the',
#   'wall.',
#   '</s>'],
#  ['<s>',
#   "i'm",
#   'the',
#   'one',
#   'who',
#   'gave',
#   'tom',
#   'that',
#   'black',
#   'eye.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'sitting',
#   'at',
#   'the',
#   'counter',
#   'with',
#   'mary.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'assumed',
#   'the',
#   'train',
#   'would',
#   'be',
#   'on',
#   'time.',
#   '</s>'],
#  ['<s>', 'who', 'the', "heck's", 'book', 'is', 'this?', '</s>'],
#  ['<s>',
#   'i',
#   'wonder',
#   'whether',
#   'tom',
#   'and',
#   'mary',
#   'are',
#   'being',
#   'sarcastic.',
#   '</s>'],
#  ['<s>', 'we', 'kept', 'hanging', 'in', 'there.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "can't",
#   'just',
#   'do',
#   'whatever',
#   'they',
#   'want.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'that',
#   'they',
#   'knew',
#   'the',
#   'area',
#   'well.',
#   '</s>'],
#  ['<s>',
#   'try',
#   'to',
#   'do',
#   'it',
#   'to',
#   'the',
#   'best',
#   'of',
#   'your',
#   'abilities.',
#   '</s>'],
#  ['<s>', 'tom', 'opened', 'the', 'door', 'and', 'went', 'out.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "don't",
#   'know',
#   'how',
#   'to',
#   'explain',
#   'how',
#   'they',
#   'did',
#   'that.',
#   '</s>'],
#  ['<s>',
#   'she',
#   'resembles',
#   'her',
#   'mother',
#   'in',
#   'every',
#   'respect.',
#   '</s>'],
#  ['<s>', 'he', 'has', 'broken', 'the', 'record.', '</s>'],
#  ['<s>', 'tom', 'attended', 'the', 'party', 'yesterday.', '</s>'],
#  ['<s>',
#   'the',
#   'guy',
#   'i',
#   'met',
#   'on',
#   'the',
#   'bus',
#   'told',
#   'me',
#   'his',
#   'name',
#   'was',
#   'tom.',
#   '</s>'],
#  ['<s>',
#   'sami',
#   'used',
#   'to',
#   'hear',
#   'sounds',
#   'coming',
#   'from',
#   'the',
#   'ceiling',
#   'of',
#   'his',
#   'room.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'most',
#   'important',
#   'discoveries',
#   'are',
#   'the',
#   'ones',
#   'that',
#   'we',
#   'cannot',
#   'anticipate.',
#   '</s>'],
#  ['<s>',
#   'they',
#   'want',
#   'to',
#   'participate',
#   'in',
#   'the',
#   'olympic',
#   'games.',
#   '</s>'],
#  ['<s>',
#   'books',
#   'are',
#   'the',
#   'windows',
#   'through',
#   'which',
#   'the',
#   'soul',
#   'looks',
#   'out.',
#   '</s>'],
#  ['<s>',
#   'though',
#   'the',
#   'best',
#   'be',
#   'in',
#   'sight,',
#   '/',
#   "it's",
#   'the',
#   'worst',
#   'i',
#   'grip',
#   'tight.',
#   '</s>'],
#  ['<s>', 'that', 'is', 'my', "father's", 'first', 'letter.', '</s>'],
#  ['<s>',
#   'sami',
#   'was',
#   'trying',
#   'to',
#   'calm',
#   'the',
#   'baby',
#   'down.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'wanted',
#   'to',
#   'live',
#   'close',
#   'to',
#   'where',
#   'they',
#   'worked.',
#   '</s>'],
#  ['<s>',
#   'antoine',
#   'louis',
#   'invented',
#   'the',
#   'guillotine,',
#   'which',
#   'was,',
#   'however,',
#   'named',
#   'after',
#   'dr.',
#   'joseph-ignace',
#   'guillotin.',
#   '</s>'],
#  ['<s>', 'we', 'ran', 'all', 'the', 'way', 'to', 'the', 'station.', '</s>'],
#  ['<s>', 'all', 'gods', 'are', 'better', 'than', 'their', 'conduct.', '</s>'],
#  ['<s>',
#   'mary',
#   'said',
#   'that',
#   'she',
#   'saw',
#   'tom',
#   'eating',
#   'at',
#   'a',
#   'picnic',
#   'table',
#   'in',
#   'the',
#   'park.',
#   '</s>'],
#  ['<s>', 'she', 'should', 'listen', 'more', 'to', 'other', 'people.', '</s>'],
#  ['<s>', 'how', 'did', 'you', 'handle', 'the', 'situation?', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'denied',
#   'they',
#   'stole',
#   'the',
#   'money.',
#   '</s>'],
#  ['<s>', "layla's", 'date', 'paid', 'for', 'the', 'food.', '</s>'],
#  ['<s>',
#   'while',
#   'the',
#   'demonstration',
#   'was',
#   'being',
#   'made,',
#   'the',
#   'president',
#   'was',
#   'taking',
#   'notes.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'john',
#   'was',
#   'their',
#   'uncle.',
#   '</s>'],
#  ['<s>', "sami's", 'theory', 'is', 'pretty', 'bizarre.', '</s>'],
#  ['<s>',
#   'i',
#   'think',
#   'this',
#   'is',
#   'the',
#   'way',
#   'it',
#   'should',
#   'be',
#   'done.',
#   '</s>'],
#  ['<s>', 'i', "wasn't", 'able', 'to', 'catch', 'the', 'ball.', '</s>'],
#  ['<s>', 'tom', 'peeked', 'through', 'the', 'curtains.', '</s>'],
#  ['<s>', "it's", 'lovely', 'weather', 'today.', '</s>'],
#  ['<s>', 'mary', 'admitted', 'she', 'forged', 'the', 'check.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'put',
#   'milk',
#   'in',
#   'their',
#   'coffee.',
#   '</s>'],
#  ['<s>', "i'm", 'to', 'go', 'there', 'today.', '</s>'],
#  ['<s>', 'he', 'was', 'impertinent', 'to', 'his', 'father.', '</s>'],
#  ['<s>',
#   'bees',
#   'always',
#   'buzz',
#   'near',
#   'the',
#   'kitchen',
#   'window.',
#   '</s>'],
#  ['<s>',
#   'rasputin',
#   'had',
#   'the',
#   'whole',
#   'russian',
#   'court',
#   'under',
#   'his',
#   'spell.',
#   '</s>'],
#  ['<s>', 'is', 'there', 'any', 'more', 'water?', '</s>'],
#  ['<s>', 'tom', 'and', 'mary', 'are', 'talking', 'together.', '</s>'],
#  ['<s>', 'i', 'want', 'tom', 'to', 'know', 'the', 'truth.', '</s>'],
#  ['<s>', 'tom', 'awoke', 'to', 'another', 'gray', 'morning.', '</s>'],
#  ['<s>',
#   'can',
#   'tatoeba',
#   'contribute',
#   'to',
#   'the',
#   'saving',
#   'of',
#   'endangered',
#   'languages?',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'say',
#   'they',
#   "don't",
#   'want',
#   'to',
#   'talk',
#   'about',
#   'that.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'troposphere',
#   'contains',
#   'three-quarters',
#   'of',
#   'the',
#   'mass',
#   'of',
#   'the',
#   'entire',
#   'atmosphere.',
#   '</s>'],
#  ['<s>', 'tom', 'was', 'in', 'the', 'shower.', '</s>'],
#  ['<s>',
#   'the',
#   'yosemite',
#   'national',
#   'park',
#   'is',
#   'one',
#   'of',
#   'the',
#   'most',
#   'beautiful',
#   'places',
#   'on',
#   'earth.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'they',
#   'hoped',
#   "they'd",
#   'be',
#   'able',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>', 'what', 'do', 'they', 'know', 'that', 'we', "don't?", '</s>'],
#  ['<s>', 'tom', 'could', 'still', 'be', 'there.', '</s>'],
#  ['<s>',
#   'i',
#   'was',
#   'going',
#   'to',
#   'ask',
#   'you',
#   'the',
#   'same',
#   'thing.',
#   '</s>'],
#  ['<s>', "tom's", 'grandfather', 'passed', 'away', 'last', 'monday.', '</s>'],
#  ['<s>', 'i', 'should', 'sue', 'them.', '</s>'],
#  ['<s>',
#   'tom',
#   'told',
#   'john',
#   'that',
#   'he',
#   'would',
#   'ask',
#   'mary',
#   'to',
#   'the',
#   'dance',
#   'only',
#   'if',
#   'john',
#   'asked',
#   'alice.',
#   '</s>'],
#  ['<s>',
#   'my',
#   'sacrifice',
#   'will',
#   'remain',
#   'forever',
#   'in',
#   'their',
#   'souls',
#   'and',
#   'my',
#   'blood',
#   'will',
#   'be',
#   'the',
#   'price',
#   'of',
#   'their',
#   'ransom.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'really',
#   "don't",
#   'want',
#   'to',
#   'walk',
#   'there',
#   'if',
#   'i',
#   "don't",
#   'have',
#   'to.',
#   '</s>'],
#  ['<s>', 'tom', 'and', 'i', "weren't", 'there.', '</s>'],
#  ['<s>',
#   'tell',
#   'me',
#   'when',
#   'the',
#   'body',
#   'gets',
#   'to',
#   'the',
#   'funerary',
#   'parlor.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "don't",
#   'know',
#   'whether',
#   'tom',
#   'still',
#   'lives',
#   'here',
#   'or',
#   'not.',
#   '</s>'],
#  ['<s>', 'i', 'lost', 'my', 'shoe', 'in', 'the', 'fire.', '</s>'],
#  ['<s>', 'sami', 'was', 'the', 'victim', 'of', 'a', 'murder.', '</s>'],
#  ['<s>',
#   'tom',
#   'says',
#   'he',
#   'and',
#   'his',
#   'friends',
#   'were',
#   'just',
#   'there',
#   'to',
#   'help.',
#   '</s>'],
#  ['<s>', 'when', 'did', 'tom', 'go', 'to', 'the', 'market?', '</s>'],
#  ['<s>',
#   'it',
#   'took',
#   'a',
#   'great',
#   'deal',
#   'of',
#   'time',
#   'to',
#   'analyze',
#   'the',
#   'data.',
#   '</s>'],
#  ['<s>',
#   'god?!',
#   'i',
#   "won't",
#   'let',
#   'my',
#   'life',
#   'be',
#   'ruled',
#   'by',
#   'a',
#   'working',
#   'hypothesis!',
#   '</s>'],
#  ['<s>',
#   'jed',
#   'works',
#   'as',
#   'a',
#   'cattle',
#   'feeder,',
#   'but',
#   'he',
#   'has',
#   'designs',
#   'on',
#   'the',
#   'whole',
#   'ranch.',
#   '</s>'],
#  ['<s>',
#   'are',
#   'there',
#   'any',
#   'girls',
#   'here',
#   'you',
#   "haven't",
#   'met',
#   'yet?',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'said',
#   'that',
#   'he',
#   'learned',
#   'how',
#   'to',
#   'do',
#   'that',
#   'the',
#   'hard',
#   'way.',
#   '</s>'],
#  ['<s>', 'tom', 'walked', 'towards', 'the', 'stairs.', '</s>'],
#  ['<s>', 'sami', 'got', 'into', 'the', 'attic.', '</s>'],
#  ['<s>', 'he', 'has', 'another', 'son.', '</s>'],
#  ['<s>',
#   'tom',
#   'might',
#   'be',
#   'gone',
#   'by',
#   'the',
#   'time',
#   'we',
#   'get',
#   'there.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'have',
#   'told',
#   'me',
#   "they're",
#   'planning',
#   'on',
#   'doing',
#   'that.',
#   '</s>'],
#  ['<s>',
#   'sami',
#   'met',
#   'layla',
#   'at',
#   'six',
#   'in',
#   'the',
#   'afternoon.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'know',
#   'those',
#   'girls',
#   'over',
#   'there',
#   'quite',
#   'well.',
#   '</s>'],
#  ['<s>', 'he', 'prefers', 'the', 'quiet.', '</s>'],
#  ['<s>',
#   'but',
#   'while',
#   'i',
#   'am',
#   'here,',
#   'do',
#   'you',
#   'think',
#   'you',
#   'could',
#   'replace',
#   'the',
#   'batteries?',
#   '</s>'],
#  ['<s>',
#   'without',
#   'the',
#   'idea',
#   'of',
#   '\u200b\u200bgod',
#   'there',
#   'is',
#   'no',
#   'clever',
#   'answer',
#   'to',
#   'the',
#   'question',
#   'about',
#   'the',
#   'reason',
#   'for',
#   'the',
#   'existence',
#   'of',
#   'the',
#   'universe.',
#   '</s>'],
#  ['<s>', 'they', 'said', 'they', 'may', 'possibly', 'do', 'that.', '</s>'],
#  ['<s>', 'my', 'mother', 'looks', 'young', 'for', 'her', 'age.', '</s>'],
#  ['<s>', "we'll", 'be', 'there', 'in', 'no', 'time.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'that',
#   'they',
#   'were',
#   'still',
#   'afraid.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'officers',
#   'arrested',
#   'three',
#   'of',
#   'the',
#   'protesters.',
#   '</s>'],
#  ['<s>', "i'm", 'used', 'to', 'these', 'things.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'that',
#   'they',
#   "weren't",
#   'coming.',
#   '</s>'],
#  ['<s>',
#   'coral',
#   'reefs',
#   'are',
#   'some',
#   'of',
#   'the',
#   'most',
#   'amazing',
#   'natural',
#   'habitats',
#   'on',
#   'earth.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'cook',
#   'put',
#   'the',
#   'food',
#   'in',
#   'the',
#   'dumb',
#   'waiter.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'committed',
#   'to',
#   'ratifying',
#   'the',
#   'decisions',
#   'made',
#   'by',
#   'mary.',
#   '</s>'],
#  ['<s>',
#   'she',
#   'succeeded',
#   'in',
#   'drawing',
#   'the',
#   'truth',
#   'from',
#   'him.',
#   '</s>'],
#  ['<s>', 'tom', 'stayed', 'on', 'the', 'sideline.', '</s>'],
#  ['<s>',
#   'i',
#   'was',
#   'a',
#   'second',
#   'lieutenant',
#   'in',
#   'the',
#   'special',
#   'forces.',
#   '</s>'],
#  ['<s>', 'could', 'you', 'direct', 'me', 'to', 'the', 'bus', 'stop?', '</s>'],
#  ['<s>',
#   'tom',
#   'wants',
#   'to',
#   'know',
#   'what',
#   'to',
#   'do',
#   'with',
#   'all',
#   'the',
#   'stuff',
#   'you',
#   'left',
#   'in',
#   'his',
#   'garage.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'know',
#   'tom',
#   "isn't",
#   'the',
#   'only',
#   'one',
#   'who',
#   'needs',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>', 'what', 'time', 'does', 'the', 'play', 'begin?', '</s>'],
#  ['<s>',
#   'my',
#   'grandmother',
#   'passed',
#   'away',
#   'peacefully',
#   'last',
#   'night.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "didn't",
#   'realize',
#   'that',
#   'tom',
#   'was',
#   'the',
#   'one',
#   'who',
#   'did',
#   'that.',
#   '</s>'],
#  ['<s>', 'we', 'just', 'want', 'the', 'truth.', '</s>'],
#  ['<s>', 'they', 'said', "they'd", 'wait.', '</s>'],
#  ['<s>', 'i', "didn't", 'understand', 'the', 'point', 'of', 'this.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'walked',
#   'down',
#   'the',
#   'stairs',
#   'together.',
#   '</s>'],
#  ['<s>', 'please', 'turn', 'down', 'the', 'music.', '</s>'],
#  ['<s>', 'tom', "wasn't", 'happy', 'with', 'the', 'results.', '</s>'],
#  ['<s>', 'who', 'is', 'there?', '</s>'],
#  ['<s>', 'tom', "didn't", 'want', 'to', 'go', 'to', 'the', 'doctor.', '</s>'],
#  ['<s>',
#   'when',
#   'mary',
#   'told',
#   'her',
#   'parents',
#   'she',
#   'wanted',
#   'to',
#   'marry',
#   'tom,',
#   'they',
#   'said',
#   'they',
#   "wouldn't",
#   'attend',
#   'the',
#   'wedding.',
#   '</s>'],
#  ['<s>', 'can', 'the', 'crisis', 'be', 'overcome?', '</s>'],
#  ['<s>', 'where', 'can', 'i', 'catch', 'the', 'number', '7', 'bus?', '</s>'],
#  ['<s>',
#   '"a"',
#   'is',
#   'the',
#   'first',
#   'of',
#   'all',
#   'letters',
#   '--',
# ...
#   'russell',
#   'was',
#   'a',
#   'brilliant',
#   'philosopher,',
#   'but',
#   'even',
#   'the',
#   'simplest',
#   'practical',
#   'task',
#   'was',
#   'quite',
#   'beyond',
#   'him.',
#   '</s>'],
#  ['<s>',
#   'tom,',
#   'could',
#   'you',
#   'keep',
#   'an',
#   'eye',
#   'on',
#   'the',
#   'kids?',
#   '</s>'],
#  ['<s>',
#   'the',
#   'gentleman',
#   'best',
#   'knows',
#   'himself',
#   'the',
#   'value',
#   'of',
#   'his',
#   'own',
#   'life.',
#   '</s>'],
#  ['<s>', 'tom', 'served', 'in', 'the', 'gulf', 'war.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'they',
#   'expect',
#   'to',
#   'do',
#   'that',
#   'on',
#   'monday.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'suspect',
#   'that',
#   'tom',
#   "isn't",
#   'telling',
#   'the',
#   'truth.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'never',
#   'even',
#   'got',
#   'a',
#   'chance',
#   'to',
#   'ask',
#   'tom',
#   'and',
#   'mary',
#   'if',
#   "they'd",
#   'help.',
#   '</s>'],
#  ['<s>',
#   'was',
#   'tom',
#   'the',
#   'one',
#   'who',
#   'showed',
#   'you',
#   'how',
#   'to',
#   'do',
#   'that?',
#   '</s>'],
#  ['<s>', 'he', 'illustrated', 'his', 'theory', 'with', 'examples.', '</s>'],
#  ['<s>', "there's", 'no', 'com', 'port', 'on', 'this', 'motherboard.', '</s>'],
#  ['<s>', 'tom', 'accompanied', 'mary', 'on', 'the', 'guitar.', '</s>'],
#  ['<s>', 'he', 'is', 'pleased', 'with', 'the', 'plan.', '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "didn't",
#   'know',
#   'they',
#   "didn't",
#   'have',
#   'enough',
#   'time',
#   'to',
#   'do',
#   'what',
#   'needed',
#   'to',
#   'be',
#   'done.',
#   '</s>'],
#  ['<s>', 'we', 'give', 'this', 'town', 'to', 'the', 'serb', 'nation.', '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'the',
#   'most',
#   'valuable',
#   'player',
#   'on',
#   'our',
#   'team.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'band',
#   'of',
#   'rain,',
#   'heading',
#   'eastwards,',
#   'will',
#   'reach',
#   'all',
#   'parts',
#   'by',
#   'the',
#   'end',
#   'of',
#   'the',
#   'day.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "don't",
#   'have',
#   'my',
#   'passport',
#   'with',
#   'me,',
#   'so',
#   'they',
#   "won't",
#   'let',
#   'me',
#   'cross',
#   'the',
#   'border.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'know',
#   'they',
#   'have',
#   'to',
#   'do',
#   'it.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'that',
#   'they',
#   "didn't",
#   'drink',
#   'coffee.',
#   '</s>'],
#  ['<s>',
#   'those',
#   'who',
#   'intended',
#   'to',
#   'stay',
#   'quickly',
#   'adopted',
#   'the',
#   'island',
#   'speech',
#   'patterns,',
#   'while',
#   'those',
#   'who',
#   'did',
#   'not,',
#   'did',
#   'not.',
#   '</s>'],
#  ['<s>',
#   'anne',
#   'went',
#   'to',
#   'the',
#   'little',
#   'avonlea',
#   'graveyard',
#   'the',
#   'next',
#   'evening',
#   'to',
#   'put',
#   'fresh',
#   'flowers',
#   'on',
#   "matthew's",
#   'grave.',
#   '</s>'],
#  ['<s>',
#   'it',
#   'was',
#   'my',
#   'turn',
#   'to',
#   'straighten',
#   'up',
#   'the',
#   'room.',
#   '</s>'],
#  ['<s>',
#   'mary',
#   "didn't",
#   'start',
#   'playing',
#   'the',
#   'violin',
#   'until',
#   'she',
#   'was',
#   'thirty',
#   'year',
#   'old.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'glanced',
#   'at',
#   'the',
#   'two',
#   'men',
#   'walking',
#   'in',
#   'front',
#   'of',
#   'me.',
#   '</s>'],
#  ['<s>', 'tom', 'is', 'the', 'author', 'of', 'three', 'books.', '</s>'],
#  ['<s>',
#   "weren't",
#   'tom',
#   'and',
#   'mary',
#   'supposed',
#   'to',
#   'do',
#   'that',
#   'by',
#   'themselves?',
#   '</s>'],
#  ['<s>',
#   'he',
#   'was',
#   'the',
#   'first',
#   'man',
#   'to',
#   'cross',
#   'the',
#   'pacific.',
#   '</s>'],
#  ['<s>', 'what', 'do', 'you', 'think', 'of', 'these', 'people?', '</s>'],
#  ['<s>', 'they', "shouldn't", 'have', 'done', 'what', 'they', 'did.', '</s>'],
#  ['<s>',
#   'think',
#   'hard',
#   'about',
#   'your',
#   'foe,',
#   'for',
#   'he',
#   'is',
#   'a',
#   'mountain',
#   'you',
#   'will',
#   'not',
#   'bring',
#   'down.',
#   'you',
#   'have',
#   'never',
#   'seen',
#   'such',
#   'a',
#   'man',
#   'nor',
#   'had',
#   'the',
#   'opportunity',
#   'to',
#   'stand',
#   'beside',
#   'him',
#   'in',
#   'battle.',
#   'you',
#   'can',
#   'not',
#   'understand',
#   'the',
#   'likes',
#   'of',
#   'such,',
#   'because',
#   'you',
#   'have',
#   'not',
#   'had',
#   'such',
#   'an',
#   'opportunity.',
#   'life',
#   'is',
#   'a',
#   'lesson.',
#   'some',
#   'are',
#   'hard',
#   'lesson,',
#   'some',
#   'unforgiving',
#   'and',
#   'damning.',
#   'some',
#   'are',
#   'irreversible',
#   'and',
#   'final.',
#   'a',
#   'man',
#   'with',
#   'nothing',
#   'to',
#   'lose',
#   'is',
#   'a',
#   'man',
#   'you',
#   'must',
#   'fear,',
#   'for',
#   'he',
#   'will',
#   'take',
#   'you',
#   'to',
#   'the',
#   'end.',
#   '</s>'],
#  ['<s>',
#   'put',
#   'the',
#   'wet',
#   'umbrella',
#   'in',
#   'this',
#   'bag,',
#   'please.',
#   '</s>'],
#  ['<s>',
#   'religious',
#   'behaviour',
#   'is',
#   'much',
#   'less',
#   'regulated',
#   'by',
#   'the',
#   'government',
#   'here',
#   'than',
#   'in',
#   'other',
#   'places.',
#   '</s>'],
#  ['<s>',
#   'sami',
#   'was',
#   'keeping',
#   'an',
#   'eye',
#   'on',
#   'his',
#   'little',
#   'brother.',
#   '</s>'],
#  ['<s>', 'tom', 'was', 'in', 'the', 'garden.', '</s>'],
#  ['<s>',
#   'a',
#   'few',
#   'words',
#   'of',
#   'portuguese',
#   'vocabulary',
#   'come',
#   'from',
#   'the',
#   'tupi.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'became',
#   'good',
#   'friends',
#   'with',
#   'the',
#   'elevator',
#   'operator',
#   'in',
#   'their',
#   'hotel.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'clearness',
#   'of',
#   'the',
#   'explanation',
#   'satisfied',
#   'him.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'know',
#   'that',
#   'they',
#   'can',
#   'trust',
#   'us.',
#   '</s>'],
#  ['<s>', 'what', 'was', 'the', 'cause', 'of', 'your', 'quarrel?', '</s>'],
#  ['<s>', 'they', 'died', 'peacefully', 'in', 'their', 'sleep.', '</s>'],
#  ['<s>',
#   'tom',
#   'set',
#   'his',
#   'homework',
#   'out',
#   'on',
#   'the',
#   'table.',
#   '</s>'],
#  ['<s>', 'sami', 'sleeps', 'with', 'the', 'light', 'on.', '</s>'],
#  ['<s>', 'tom', 'and', 'mary', 'said', 'they', "weren't", 'jealous.', '</s>'],
#  ['<s>',
#   '"now,"',
#   'he',
#   'said',
#   'to',
#   'the',
#   'lady,',
#   '"all',
#   'we',
#   'want',
#   'is',
#   'a',
#   'drop',
#   'of',
#   'the',
#   "maiden's",
#   'blood."',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'never',
#   'told',
#   'me',
#   'that',
#   'they',
#   'were',
#   'from',
#   'boston.',
#   '</s>'],
#  ['<s>',
#   'this',
#   'small',
#   "car's",
#   'gearbox',
#   'is',
#   'underneath',
#   'the',
#   'engine.',
#   '</s>'],
#  ['<s>',
#   'many',
#   'fragile',
#   'species',
#   'are',
#   'on',
#   'the',
#   'verge',
#   'of',
#   'extinction.',
#   '</s>'],
#  ['<s>', 'have', 'the', 'decency', 'to', 'keep', 'quiet.', '</s>'],
#  ['<s>',
#   'actually,',
#   'maria',
#   'is',
#   'a',
#   'modern',
#   'young',
#   'woman,',
#   'however,',
#   'she',
#   'is',
#   'as',
#   'superstitious',
#   'as',
#   'my',
#   'grandmother.',
#   '</s>'],
#  ['<s>', "tom's", 'father', 'was', 'a', 'preacher.', '</s>'],
#  ['<s>',
#   'the',
#   'girls',
#   'talked',
#   'about',
#   'boys,',
#   'and',
#   'the',
#   'boys',
#   'talked',
#   'about',
#   'girls.',
#   '</s>'],
#  ['<s>', 'mary', 'painted', 'the', 'house.', '</s>'],
#  ['<s>', 'i', 'asked', 'tom', 'to', 'play', 'the', 'guitar.', '</s>'],
#  ['<s>', 'tom', 'was', 'always', 'the', 'strong', 'one.', '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'the',
#   'only',
#   'one',
#   'likely',
#   'to',
#   'be',
#   'able',
#   'to',
#   'help',
#   'you.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   "aren't",
#   'as',
#   'poor',
#   'as',
#   'most',
#   'people',
#   'think',
#   'they',
#   'are.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'said',
#   'mary',
#   'ought',
#   'to',
#   'do',
#   'that',
#   'in',
#   'the',
#   'other',
#   'room.',
#   '</s>'],
#  ['<s>',
#   'then',
#   'dymas',
#   'brave',
#   '/',
#   'and',
#   'hypanis',
#   'by',
#   "comrades'",
#   'hands',
#   'are',
#   'slain.',
#   '/',
#   'nor,',
#   'panthus,',
#   'thee',
#   'thy',
#   'piety',
#   'can',
#   'save,',
#   '/',
#   'nor',
#   "e'en",
#   "apollo's",
#   'wreath',
#   'preserve',
#   'thee',
#   'from',
#   'the',
#   'grave.',
#   '</s>'],
#  ['<s>',
#   'i',
#   "didn't",
#   'like',
#   'the',
#   'answer',
#   'that',
#   'tom',
#   'gave',
#   'me.',
#   '</s>'],
#  ['<s>', 'tom', 'handed', 'mary', 'the', 'key.', '</s>'],
#  ['<s>', 'hire', 'a', 'minivan', 'by', 'the', 'hour.', '</s>'],
#  ['<s>', "that's", 'the', 'ticket.', '</s>'],
#  ['<s>', 'i', 'know', 'it', "wasn't", 'them.', '</s>'],
#  ['<s>', 'luckily,', 'tom', "wasn't", 'killed', 'in', 'the', 'war.', '</s>'],
#  ['<s>', 'teach', 'them', 'how', 'to', 'make', 'a', 'salad.', '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'constantly',
#   'finding',
#   'fault',
#   'with',
#   'everything',
#   'mary',
#   'does.',
#   '</s>'],
#  ['<s>', 'he', 'was', 'eager', 'to', 'tie', 'the', 'knot.', '</s>'],
#  ['<s>', 'your', 'father', 'is', 'dead', 'now.', '</s>'],
#  ['<s>', 'he', 'has', 'the', 'key', 'to', 'her', 'heart.', '</s>'],
#  ['<s>',
#   'tom',
#   'said',
#   'that',
#   'mary',
#   'was',
#   'likely',
#   'to',
#   'be',
#   'the',
#   'next',
#   'one',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>', 'the', 'old', 'shrine', 'used', 'to', 'stand', 'there.', '</s>'],
#  ['<s>',
#   'when',
#   'was',
#   'the',
#   'last',
#   'time',
#   'you',
#   'had',
#   'a',
#   'really',
#   'good',
#   'cry?',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'decorated',
#   'the',
#   'gym',
#   'with',
#   'balloons.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'is',
#   'going',
#   'to',
#   'miss',
#   'the',
#   'train',
#   'if',
#   'he',
#   "doesn't",
#   'hurry.',
#   '</s>'],
#  ['<s>',
#   'when',
#   'i',
#   'left',
#   'the',
#   'train',
#   'station,',
#   'i',
#   'saw',
#   'a',
#   'man.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'that',
#   'they',
#   'felt',
#   'threatened.',
#   '</s>'],
#  ['<s>',
#   "parents'",
#   'love',
#   'can',
#   'sometimes',
#   'be',
#   'so',
#   'overwhelming',
#   'that',
#   'you',
#   "can't",
#   'breathe.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'called',
#   'his',
#   'father',
#   'to',
#   'wish',
#   'him',
#   'a',
#   'happy',
#   "father's",
#   'day.',
#   '</s>'],
#  ['<s>',
#   'they',
#   "don't",
#   'care',
#   'about',
#   'doing',
#   'harm',
#   'to',
#   'themselves.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'thought',
#   'that',
#   'tom',
#   'would',
#   'look',
#   'more',
#   'like',
#   'his',
#   'brother.',
#   '</s>'],
#  ['<s>',
#   'they',
#   'hope',
#   'that',
#   'they',
#   "don't",
#   'botch',
#   'the',
#   'job.',
#   '</s>'],
#  ['<s>', 'do', 'you', 'read', 'something', 'besides', 'the', 'bible?', '</s>'],
#  ['<s>',
#   'i',
#   "don't",
#   'think',
#   'tom',
#   'and',
#   'mary',
#   'feel',
#   'the',
#   'same',
#   'way.',
#   '</s>'],
#  ['<s>',
#   'the',
#   'number',
#   'of',
#   'facebook',
#   'members',
#   'is',
#   'higher',
#   'than',
#   'the',
#   'u.s.',
#   'population.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'were',
#   'going',
#   'to',
#   'do',
#   'that',
#   'themselves.',
#   '</s>'],
#  ['<s>',
#   'they',
#   'forgot',
#   'i',
#   'am',
#   'the',
#   'ceo',
#   'of',
#   'this',
#   'company.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'hope',
#   'to',
#   'contact',
#   'other',
#   'esperantists',
#   'through',
#   'the',
#   'radio,',
#   'as',
#   "i'm",
#   'a',
#   'radio',
#   'amateur.',
#   'my',
#   'call',
#   'sign',
#   'is',
#   'f5nqw.',
#   '</s>'],
#  ['<s>',
#   'when',
#   'i',
#   'was',
#   'in',
#   'elementary',
#   'school',
#   'i',
#   'thought,',
#   'from',
#   'the',
#   'bottom',
#   'of',
#   'my',
#   'heart,',
#   'that',
#   'the',
#   'teachers',
#   'were',
#   'great',
#   'people',
#   'and',
#   'i',
#   'was',
#   'influenced',
#   'by',
#   'the',
#   "teachers'",
#   'attitudes',
#   'and',
#   'moral',
#   'lessons,',
#   'but',
#   'middle',
#   'school',
#   'was',
#   'just',
#   'a',
#   'business',
#   'like',
#   'any',
#   'other.',
#   '</s>'],
#  ['<s>', 'tom', "doesn't", 'understand', 'the', 'situation.', '</s>'],
#  ['<s>',
#   'everybody',
#   'knows',
#   'tom',
#   'and',
#   'i',
#   'like',
#   'each',
#   'other.',
#   '</s>'],
#  ['<s>', 'where', 'are', 'the', 'friends?', '</s>'],
#  ['<s>',
#   'he',
#   'was',
#   'considered',
#   'very',
#   'qualified',
#   'for',
#   'the',
#   'job.',
#   '</s>'],
#  ['<s>',
#   'they',
#   'are',
#   'fulfilling',
#   'the',
#   'commandment',
#   'to',
#   'take',
#   'in',
#   'guests.',
#   '</s>'],
#  ['<s>',
#   'english',
#   'is',
#   'the',
#   'language',
#   'of',
#   'unlimited',
#   'possibilities.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'said',
#   'he',
#   'knew',
#   'that',
#   'mary',
#   "wouldn't",
#   'win',
#   'the',
#   'race.',
#   '</s>'],
#  ['<s>',
#   'what',
#   'do',
#   'you',
#   'want',
#   'more',
#   'than',
#   'anything',
#   'else',
#   'in',
#   'the',
#   'world?',
#   '</s>'],
#  ['<s>',
#   'you',
#   'can',
#   'upgrade',
#   'your',
#   'computer',
#   'with',
#   'more',
#   'random',
#   'access',
#   'memory',
#   'to',
#   'make',
#   'the',
#   'pc',
#   'faster.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'have',
#   'decided',
#   'not',
#   'to',
#   'talk',
#   'to',
#   'their',
#   'children',
#   'in',
#   'french',
#   'anymore.',
#   '</s>'],
#  ['<s>', 'what', 'is', 'the', 'language', 'spoken', 'in', 'mexico?', '</s>'],
#  ['<s>', 'they', 'got', 'away', 'from', 'the', 'place.', '</s>'],
#  ['<s>',
#   'tom',
#   'admitted',
#   'that',
#   'he',
#   'was',
#   'the',
#   'one',
#   'who',
#   'had',
#   'stolen',
#   "mary's",
#   'money.',
#   '</s>'],
#  ['<s>',
#   'i',
#   'figured',
#   'out',
#   'every',
#   'word',
#   'in',
#   'the',
#   'crossword',
#   'puzzle',
#   'except',
#   'the',
#   'last',
#   'one.',
#   '</s>'],
#  ['<s>', 'i', "can't", 'play', 'the', 'accordion', 'very', 'well.', '</s>'],
#  ['<s>', 'they', 'knew', 'they', 'were', 'cheating.', '</s>'],
#  ['<s>', "that's", 'the', 'real', 'reason.', '</s>'],
#  ['<s>', 'do', 'the', 'best', 'you', 'can.', '</s>'],
#  ['<s>',
#   'in',
#   'this',
#   'section,',
#   'the',
#   'composer',
#   'modulates',
#   'to',
#   'many',
#   'different',
#   'keys.',
#   '</s>'],
#  ['<s>',
#   'so',
#   'kann',
#   'also',
#   'die',
#   'mathematik',
#   'definiert',
#   'werden',
#   'als',
#   'diejenige',
#   'wissenschaft,',
#   'in',
#   'der',
#   'wir',
#   'niemals',
#   'das',
#   'kennen,',
#   'worüber',
#   'wir',
#   'sprechen,',
#   'und',
#   'niemals',
#   'wissen,',
#   'ob',
#   'das,',
#   'was',
#   'wir',
#   'sagen,',
#   'wahr',
#   'ist.',
#   '</s>'],
#  ['<s>', 'tom', 'has', 'to', 'get', 'to', 'the', 'hospital.', '</s>'],
#  ['<s>', 'tom', 'and', 'mary', 'say', 'that', 'they', 'know', 'you.', '</s>'],
#  ['<s>',
#   'is',
#   'there',
#   'something',
#   "you're",
#   'not',
#   'telling',
#   'us?',
#   '</s>'],
#  ['<s>',
#   'i',
#   'think',
#   'that',
#   'tom',
#   "shouldn't",
#   'tell',
#   'mary',
#   'about',
#   'the',
#   'accident.',
#   '</s>'],
#  ['<s>', 'hang', 'on', 'to', 'them.', '</s>'],
#  ['<s>', 'the', 'situation', 'got', 'out', 'of', 'their', 'control.', '</s>'],
#  ['<s>', 'they', 'told', 'me', 'that', "they'd", 'be', 'late.', '</s>'],
#  ['<s>',
#   'i',
#   'think',
#   'that',
#   'tom',
#   'was',
#   'the',
#   'one',
#   'who',
#   'was',
#   'supposed',
#   'to',
#   'tell',
#   'mary',
#   'she',
#   'needed',
#   'to',
#   'do',
#   'that.',
#   '</s>'],
#  ['<s>',
#   'we',
#   'will',
#   'post',
#   'the',
#   'announcement',
#   'in',
#   'all',
#   'the',
#   'staff',
#   'lounges.',
#   '</s>'],
#  ['<s>', 'tom', 'washed', 'himself', 'in', 'the', 'stream.', '</s>'],
#  ['<s>', 'this', 'happened', 'often', 'in', 'the', 'spring.', '</s>'],
#  ['<s>',
#   '"...hey...hey,',
#   'teacher!"',
#   '"eh?',
#   'oh."',
#   '"are',
#   'you',
#   'really',
#   'ok?',
#   "shouldn't",
#   'you',
#   'cancel',
#   'the',
#   'lesson?"',
#   '</s>'],
#  ['<s>', 'tom', 'folded', 'the', 'napkins', 'carefully.', '</s>'],
#  ['<s>', 'who', 'said', 'you', 'could', 'take', 'the', 'car?', '</s>'],
#  ['<s>', 'tom', 'is', 'the', 'perfect', 'guy', 'for', 'you.', '</s>'],
#  ['<s>',
#   'tycho',
#   'brahe',
#   'observed',
#   'the',
#   'great',
#   'comet',
#   'of',
#   '1577.',
#   '</s>'],
#  ['<s>', 'he', 'explained', 'why', 'he', 'was', 'there.', '</s>'],
#  ['<s>', 'he', 'is', 'accustomed', 'to', 'braving', 'the', 'cold.', '</s>'],
#  ['<s>',
#   'my',
#   'grandfather',
#   'often',
#   "doesn't",
#   'remember',
#   'what',
#   'happened',
#   'yesterday',
#   'but',
#   'can',
#   'describe',
#   'in',
#   'detail',
#   'what',
#   'happened',
#   'forty',
#   'years',
#   'ago.',
#   '</s>'],
#  ['<s>', 'he', 'looked', 'me', 'right', 'in', 'the', 'eye.', '</s>'],
#  ['<s>',
#   'my',
#   'mother',
#   'being',
#   'ill,',
#   'i',
#   'looked',
#   'after',
#   'her.',
#   '</s>'],
#  ['<s>',
#   'did',
#   'you',
#   'finish',
#   'the',
#   'assigned',
#   'readings',
#   'in',
#   'the',
#   'textbook?',
#   '</s>'],
#  ['<s>',
#   "we've",
#   'been',
#   'unable',
#   'to',
#   'determine',
#   'the',
#   'cause.',
#   '</s>'],
#  ['<s>',
#   'he',
#   'lands',
#   'in',
#   'a',
#   'garden',
#   'and',
#   'knocks',
#   'at',
#   'the',
#   'door.',
#   '</s>'],
#  ['<s>',
#   'tom',
#   'and',
#   'mary',
#   'said',
#   'that',
#   'they',
#   'felt',
#   'very',
#   'sleepy.',
#   '</s>'],
#  ['<s>',
#   'what',
#   'is',
#   'wrong',
#   'with',
#   'me',
#   'paying',
#   'the',
#   'bill?',
#   '</s>'],
#  ...]

# %%
def remove_rare_words(data, vocab, mincount = 1):
    '''
    Parameters:
    data (list of lists): each list is a sentence of the text 
    vocab (dictionary): {word: no of times it appears in the text}
    mincount(int): the minimum count 
    
    Returns: 
    data_with_unk(list of lists): data after replacing rare words with <unk> token
    '''
    # replace words in data that are not in the vocab 
    # or have a count that is below mincount
    data_with_unk = []

    ## FILL CODE
    for sentence in train_data:
        sentence_updated=[]
        for word in sentence:
            if vocab[word] <= mincount or word not in vocab:
                sentence_updated.append("<unk>")
            else:
                sentence_updated.append(word)
                
        data_with_unk.append(sentence_updated)
    return data_with_unk

# %%
print("remove rare words")
train_data = remove_rare_words(train_data, vocab, mincount = 1)
valid_data = remove_rare_words(valid_data, vocab, mincount = 1)
#train_data
print(train_data[0])
# Out:
# remove rare words
# ['<s>', 'my', '<unk>', "don't", 'speak', '<unk>', '</s>']

# %%
def build_ngram(data, n):
    '''
    Parameters:
    data (list of lists): each list is a sentence of the text 
    n (int): size of the n-gram
    
    Returns:
    proba (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    
    
    '''
    total_number_words = 0
    counts = defaultdict(lambda: defaultdict(lambda: 0.0))

    for sentence in data:
        sentence = tuple(sentence)
        ## FILL CODE
        # dict can be indexed by tuples
        # store in the same dict all the ngrams
        # by using the context as a key and the word as a value
        for i in range(len(sentence)):
            total_number_words +=1
            for j in range(n):
                if i-j < 0:
                    break
                counts[sentence[i-j:i]][sentence[i]] +=1 
                           

    proba  = defaultdict(lambda: defaultdict(lambda: 0.0))
    # Build the probabilities from the counts
    # Be careful with how you normalize!

    for context in counts.keys():
    ## FILL CODE
        den =0
        for k in counts[context].keys():
            den += counts[context][k]
        for k in counts[context].keys():
            proba[context][k] = counts[context][k]/den 
    
    return proba

# %%
# RUN TO BUILD NGRAM MODEL

n = 2
print("build ngram model with n = ", n)
model = build_ngram(train_data, n)
# Out:
# build ngram model with n =  2

# %% [markdown]
# Here, implement a recursive function over shorter and shorter context to compute a "stupid backoff model". An interpolation model can also be implemented this way.

# %%
def get_prob(model, context, w):
    '''
    Parameters: 
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    } 
    context (list of strings): a sentence
    w(string): the word we need to find it's probability given the context
    
    Retunrs:
    prob(float): probability of this word given the context 
    '''

    # code a recursive function over 
    # smaller and smaller context
    # to compute the backoff model
    
    ## FILL CODE

    if context in model and w in model[context]:
        return model[context][w]
    else:
        return 0.4*get_prob(model, context[1:], w)

# %%
def perplexity(model, data, n):
    '''
    Parameters: 
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    } 
    data (list of lists): each list is a sentence of the text
    n(int): size of the n-gram
    
    Retunrs:
    prep(float): the preplexity of the model 
    '''
    ## FILL CODE
    perp, T = 0.0, 0
    for sentence in data:
        sentence = tuple(sentence)
        for i in range(1, len(sentence)):
            nc = min(n-1, i)
            context = sentence[i-nc:i]
            perp += -math.log(get_prob(model, context, sentence[i]))
            T += 1
    perp = math.exp(perp/T)
    return perp

# %%
# COMPUTE PERPLEXITY ON VALIDATION SET

print("The perplexity is", perplexity(model, valid_data, n=n))
# Out:
# The perplexity is 21.668651814592515

# %%
def get_proba_distrib(model, context):
    ## need to get the the words after the context and their probability of appearance
    ## after this context 
    '''
    Parameters: 
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    context (list of strings): the sentence we need to find the words after it and 
    thier probabilites
    
    Retunrs:
    words_and_probs(dic): {word: probability of word given context}
    
    '''
    # code a recursive function over context
    # to find the longest available ngram
    
    ## FILL CODE
    
    if context in model:
        return model[context]
    else:
        return get_proba_distrib(model, context[1:])

# %%
def generate(model):
    '''
    Parameters: 
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    
    Retunrs:
    sentence (list of strings): a sentence sampled according to the language model. 
    

    '''
    # generate a sentence. A sentence starts with a <s> and ends with a </s>
    # Possiblly a use function is:
    # np.random.choice(x, 1, p = y)

    # where x is a list of things to sample from
    # and y is a list of probability (of the same length as x)
    sentence = ["<s>"]
    while sentence[-1] != "</s>" and len(sentence)<100:
        ## FILL CODE
        proba = get_proba_distrib(model, tuple(sentence))
        w = np.random.choice((list(proba.keys())), 1, p = list(proba.values()))
        sentence.append(w[0])
    return sentence

# %%
# GENERATE A SENTENCE FROM THE MODEL

print("Generated sentence: ",generate(model))
# Out:
# Generated sentence:  ['<s>', 'my', 'hat', 'man', 'is', 'a', 'problem', 'already.', '</s>']

# %% [markdown]
# Once you are done implementing the model, evaluation and generation code, you can try changing the value of `n`, and play with a larger training set (`train2.txt` and `valid2.txt`). You can also try to implement an interpolation model.
